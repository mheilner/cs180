# %% [markdown]
# <a href="https://colab.research.google.com/github/porterjenkins/CS180/blob/main/data_science_labs/data_science_lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><p><b>After clicking the "Open in Colab" link, copy the notebook to your own Google Drive before getting started, or it will not save your work</b></p>

# %% [markdown]
# # BYU CS 180 Lab 5: Cereal Data

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Everyone loves cereal. But have you ever thought deeply about your cereal? Well now is your chance to take a data driven view of your breakfast.
#
# ![image-20210816-203922.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Getting Started:
# Download the data from github. Run the code below to download the data that you'll be using in this lab.
#
# You may use pandas, numpy, matplotlib and/or seaborn for these excercises.
#
# You can use/read their respective documentation in the links below (only if you need too, it's not required for the lab):
#
# *   Seaborn [Documentation]("https://seaborn.pydata.org/tutorial.html")
# *   Matplotlib [Documentation]("https://matplotlib.org/stable/api/index.html")
# *   Numpy [Documentation]("https://numpy.org/doc/1.23/user/index.html#user")
# *   Pandas [Documentation]("https://pandas.pydata.org/docs/user_guide/index.html#user-guide")

# %%
# !wget https://raw.githubusercontent.com/porterjenkins/cs180-intro-data-science/master/data/cereal.csv
# Out:
# --2023-02-08 22:03:08--  https://raw.githubusercontent.com/porterjenkins/cs180-intro-data-science/master/data/cereal.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4985 (4.9K) [text/plain]
# Saving to: ‘cereal.csv’
#
# cereal.csv          100%[===================>]   4.87K  --.-KB/s    in 0s
#
# 2023-02-08 22:03:08 (51.6 MB/s) - ‘cereal.csv’ saved [4985/4985]

# %% [markdown]
# ## Exercise 1: Protein Powder
# Carbs, fats and proteins are the three primary macro nutrients. Create a figure plotting the distribution of each of these macro nutrients together (i.e., three distributions on a single plot). Make sure to provide a legend.

# %%
# Enter all of your code for exercise 1 here. Feel free to add more cells if you need to:
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import pandas as pd

cdf = pd.read_csv('cereal.csv')
macros = cdf[['protein','fat','carbo']]
# print(cdf.head())
# print(cdf.info())


# Plotting
sns.displot(macros, bins= 25)
plt.title('Distrubution of Macronutirent Content in Various Cereals')
plt.xlabel('Grams')
plt.ylabel('Count')

# Alt Code
# cdf[['protein','fat','carbo']].plot(kind='kde')
# cdf[['protein','fat','carbo']].plot.hist(bins=25)
# Out:
# Text(16.601536458333328, 0.5, 'Count')

# %% [markdown]
# ## Exercise 2: Sugar Daddy
# Get a list of the top 5 most sugary cereals and the 5 least sugary cereals.

# %%
# Enter all of your code for exercise 2 here. Feel free to add more cells if you need to:
sCdf = cdf.sort_values(by='sugars', ascending=False)

# This is the code to make a single list of the top 5 and bottom 5 combinde. I was told to split them up to make them more distinguishable
# sugars = sCdf.head().append(sCdf.tail(), ignore_index=True)
# sugars[['name', 'sugars']]

print('Most Sugary Cereals')
sCdf.head()[['name', 'sugars']]
# Out:
# Most Sugary Cereals
#                      name  sugars
# 66                 Smacks      15
# 30           Golden Crisp      15
# 70      Total Raisin Bran      14
# 52  Post Nat. Raisin Bran      14
# 6             Apple Jacks      14

# %%
print('Least Sugary Cereals')
sCdf.tail()[['name', 'sugars']]
# Out:
# Least Sugary Cereals
#                       name  sugars
# 55            Puffed Wheat       0
# 54             Puffed Rice       0
# 20  Cream of Wheat (Quick)       0
# 63          Shredded Wheat       0
# 57          Quaker Oatmeal      -1

# %% [markdown]
# ## Exercise 3: Cereal Killer
# Get a list of the top 5 highest rated and lowest rated cereals.

# %%
# Enter all of your code for exercise 3 here. Feel free to add more cells if you need to:
rCdf = cdf.sort_values('rating', ascending=False)

# This is the code to make a single list of the top 5 and bottom 5 combinde. I was told to split them up to make them more distinguishable
# rating = rCdf.head().append(rCdf.tail(), ignore_index=True)
# rating[['name', 'rating']]

print('Highest Rated Cereals')
rCdf.head()[['name', 'rating']]
# Out:
# Highest Rated Cereals
#                          name     rating
# 3   All-Bran with Extra Fiber  93.704912
# 64     Shredded Wheat 'n'Bran  74.472949
# 65  Shredded Wheat spoon size  72.801787
# 0                   100% Bran  68.402973
# 63             Shredded Wheat  68.235885

# %%
print('Highest Rated Cereals')
rCdf.tail()[['name', 'rating']]
# Out:
# Highest Rated Cereals
#                      name     rating
# 14            Cocoa Puffs  22.736446
# 18          Count Chocula  22.396513
# 35       Honey Graham Ohs  21.871292
# 12  Cinnamon Toast Crunch  19.823573
# 10           Cap'n'Crunch  18.042851

# %% [markdown]
# ## Exercise 4: America
# Quantify the relationship between sugar and ratings.
#
# Make a plot to visualize this relationship. Superimpose a best fit line (with seaborn) to describe the relationship. It may be helpful to look at the [seaborn regplot documentation]("https://seaborn.pydata.org/generated/seaborn.regplot.html").

# %%
# Make the plot for the data visualization and line of best fit here:
sns.regplot(data=cdf, x='sugars', y='rating')

# %% [markdown]
# Calculate a correlation statistic describing the relationship between sugar and ratings  (i.e., r or r squared).

# %%
# Calculate the statistic using this cell:
# cdf['sugars']
# cdf['rating']
np.corrcoef(cdf['sugars'], cdf['rating'])
# Out:
# array([[ 1.        , -0.75967466],
#        [-0.75967466,  1.        ]])

# %% [markdown]
# Write a statement in plain English interpreting this statistic.

# %% [markdown]
# By calculating the correlation coeffecient above, we can see that there is a negative correlation between sugar content in cereal and the rating of the cereal. We can say that about 75% of this variability in rating can be explained by the amount of sugar in the cereal.
#
# This is of course difficult to say for sure and we cannot imply causality in this data.

# %% [markdown]
# ## Exercise 5: America Part 2
# Make five plots comparing the relationships of carbo, sugars, calories, protein, and fat with rating.

# %%
# Write your code to compare the various variables with rating below:
sns.regplot(data=cdf, x='carbo', y='rating')
plt.figure()
sns.regplot(data=cdf, x='sugars', y='rating')
plt.figure()
sns.regplot(data=cdf, x='calories', y='rating')
plt.figure()
sns.regplot(data=cdf, x='protein', y='rating')
plt.figure()
sns.regplot(data=cdf, x='fat', y='rating')

# %% [markdown]
# Of the variables carbo, sugars, calories, protein, and fat, which has the strongest relationship with rating? Justify your answer.

# %%
print('Sugars and Rating: ', np.corrcoef(cdf['sugars'], cdf['rating']))
print('Calories and Rating: ',np.corrcoef(cdf['calories'], cdf['rating']))
print('Protein and Rating: ',  np.corrcoef(cdf['protein'], cdf['rating']))
print('Carbs and Rating: ',  np.corrcoef(cdf['carbo'], cdf['rating']))
print('Fat and Rating: ',  np.corrcoef(cdf['fat'], cdf['rating']))
# Out:
# Sugars and Rating:  [[ 1.         -0.75967466]
#  [-0.75967466  1.        ]]
# Calories and Rating:  [[ 1.         -0.68937603]
#  [-0.68937603  1.        ]]
# Protein and Rating:  [[1.         0.47061846]
#  [0.47061846 1.        ]]
# Carbs and Rating:  [[1.         0.05205466]
#  [0.05205466 1.        ]]
# Fat and Rating:  [[ 1.         -0.40928366]
#  [-0.40928366  1.        ]]

# %% [markdown]
# Using visual analyses, the strongest relationships come with sugars, calories, and protein. Fat and carbohydrates are not as correlated. In order to verify my answer, I checked the correlation coefficient of these 3 variables and still sugars is the most strongly correlated to rating of the cereal. I think this makes sense because often people look closest (negatively) at the sugar content and calories and (positively) at the portein content. I am not surprised that there could be a possible connection between the sugar content and how people feel generally about the particular cereal.

# %% [markdown]
# ## Exercise 6: Preparing for Mt. Everest
# Do the same as you did with exercise 5, but instead compare carbo, sugars, protein, and fat with calories.

# %%
# Write your code to compare the various variables with calories below:
sns.regplot(data=cdf, x='carbo', y='calories')
plt.figure()
sns.regplot(data=cdf, x='sugars', y='calories')
plt.figure()
sns.regplot(data=cdf, x='protein', y='calories')
plt.figure()
sns.regplot(data=cdf, x='fat', y='calories')

# %%
print('Carbo and Cals: ', np.corrcoef(cdf['carbo'], cdf['calories']))
print('Sugar and Cals: ', np.corrcoef(cdf['sugars'], cdf['calories']))
print('Protein and Cals: ', np.corrcoef(cdf['protein'], cdf['calories']))
print('Fat and Cals: ', np.corrcoef(cdf['fat'], cdf['calories']))
# Out:
# Carbo and Cals:  [[1.         0.25068091]
#  [0.25068091 1.        ]]
# Sugar and Cals:  [[1.         0.56234029]
#  [0.56234029 1.        ]]
# Protein and Cals:  [[1.         0.01906607]
#  [0.01906607 1.        ]]
# Fat and Cals:  [[1.         0.49860981]
#  [0.49860981 1.        ]]

# %% [markdown]
# Of the variables carbo, sugars, protein, and fat, which has the strongest relationship with calories? Justify your answer.

# %% [markdown]
# Of the relationships above, the strongest correlation comes with sugars content and calories. This makes sense because sugary cereal is often not targeted to be healthy cereals. I would imagine that most cereals with high sugar are not trying to have low calories and that most low sugar cereals are purposefully low sugar and want to be targeting people who are looking for a more healthful option.

# %% [markdown]
# ## Exercise 7: It’s Hot and It's Cold
# The type column has two values: H='hot' and C='cold'. What is the average rating of each type?

# %%
# Write your code to get the average rating by type of cereal below:
hot = cdf[cdf['type']=='H']['rating'].mean()
cold = cdf[cdf['type']=='C']['rating'].mean()
print(f' the mean rating for hot cereal is: {hot}')
print(f' the mean rating for cold cereal is: {cold}')
# Out:
#  the mean rating for hot cereal is: 56.73770833333334
#  the mean rating for cold cereal is: 42.09521836486486

# %% [markdown]
# ## Exercise 8: Captain Crunch the Numbers
# Provide one additional insight from this dataset that you found interesting. Create at least one figure and explain why the figure was interesting to you.

# %%
# Create the extra plot below:
mfr = cdf.groupby('mfr').mean()['rating']
mfr.plot(kind='bar')
plt.xlabel('Manufacturer')
plt.ylabel('Average Rating')
plt.title('Average Cereal Rating by Manufacturers')
plt.show()

# %% [markdown]
# Through visualizing this plot above that plots the manufacturer verses there average rating, you can see that mfr N is by far the highest rated manufacturer. I am sure that pulling sales data as you compare this with the average macro content of N's cereals, you could see a very interesting correlation.
