# %% [markdown]
# Midterm 1

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# QUESTIONS 1-5
# HR Diagram
#
# The first set of questions will be from creating our own HR diagram. HR stands for Hertzsprung-Russell. Hertzsprung and Russell were two first astronomers to discover the relationship between a star's luminosity and its temperature. This is a very important diagram in studying about stars, and we get to create one from raw data.
#
# After you've read in the data on your file, plot the data with the following specifications:
#
# Use a log-log scatter plot to plot the data. We use a log-log plot because we're dealing with values with various magnitudes (we may have one value be 10, while another may be 100,000).
# The x-axis on this plot should be temperature
# The y-axis should be luminosity.
# Color the scatter plot points according to their star type.
# Important: you must use a log-log plot!  (See, for example, https://www.geeksforgeeks.org/how-to-plot-logarithmic-axes-in-matplotlib/  for some discussion)

# %%
# Read in the data
star = pd.read_csv('star_stats.csv')
# Out:
#      temperature     luminosity     radius  absolute_magnitude star_color  \
# 0           3068       0.002400     0.1700               16.12        Red
# 1           3042       0.000500     0.1542               16.60        Red
# 2           2600       0.000300     0.1020               18.70        Red
# 3           2800       0.000200     0.1600               16.65        Red
# 4           1939       0.000138     0.1030               20.06        Red
# ..           ...            ...        ...                 ...        ...
# 235        38940  374830.000000  1356.0000               -9.93       Blue
# 236        30839  834042.000000  1194.0000              -10.63       Blue
# 237         8829  537493.000000  1423.0000              -10.73      White
# 238         9235  404940.000000  1112.0000              -11.23      White
# 239        37882  294903.000000  1783.0000               -7.80       Blue
#
#     spectral_class    star_type
# 0                M  Brown Dwarf
# 1                M  Brown Dwarf
# 2                M  Brown Dwarf
# 3                M  Brown Dwarf
# 4                M  Brown Dwarf
# ..             ...          ...
# 235              O  Hyper Giant
# 236              O  Hyper Giant
# 237              A  Hyper Giant
# 238              A  Hyper Giant
# 239              O  Hyper Giant
#
# [240 rows x 7 columns]

# %%
# Question 1: How many stary types are there
types = star.groupby('star_type')
types['star_type'].count()
# Out:
# star_type
# Brown Dwarf      40
# Hyper Giant      40
# Main Sequence    40
# Red Dwarf        40
# Super Giant      40
# White Dwarf      40
# Name: star_type, dtype: int64

# %%
# Log Log Plot
sns.scatterplot(data=star, x='temperature', y='luminosity', hue='star_type')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# s = star[star['star_type']=='Main Sequence']
# s = star[star['star_type']=='Red Dwarf'].sort_values(by='temperature')
# s = star[star['star_type']=='White Dwarf'].sort_values(by='temperature')
s = star[star['star_type']=='Super Giant'].sort_values(by='luminosity')
s
# 74k < 888k
# Out:
#      temperature  luminosity  radius  absolute_magnitude star_color  \
# 104        11096    112000.0    12.0              -5.910       Blue
# 46          3575    123000.0    45.0              -6.780        Red
# 102        23000    127000.0    36.0              -5.760       Blue
# 165         7282    131000.0    24.0              -7.220       Blue
# 108        24345    142000.0    57.0              -6.240       Blue
# 42          3270    150000.0    88.0              -6.020        Red
# 166        19923    152000.0    73.0              -5.690       Blue
# 48          3625    184000.0    84.0              -6.740        Red
# 107        12893    184000.0    36.0              -6.340       Blue
# 43          3200    195000.0    17.0              -7.220        Red
# 167        26373    198000.0    39.0              -5.830       Blue
# 40          3826    200000.0    19.0              -6.930        Red
# 47          3574    200000.0    89.0              -5.240        Red
# 49         33750    220000.0    26.0              -6.100       Blue
# 160        25390    223000.0    57.0              -5.920       Blue
# 225        18734    224780.0    46.0              -7.450       Blue
# 105        14245    231000.0    42.0              -6.120       Blue
# 103        17120    235000.0    83.0              -6.890       Blue
# 164         8927    239000.0    35.0              -7.340       Blue
# 100        33300    240000.0    12.0              -6.500       Blue
# 220        23678    244290.0    35.0              -6.270       Blue
# 163         5752    245000.0    97.0              -6.630       Blue
# 224        16787    246730.0    62.0              -6.350       Blue
# 161        11567    251000.0    36.0              -6.245       Blue
# 44          3008    280000.0    25.0              -6.000        Red
# 45          3600    320000.0    29.0              -6.600        Red
# 221        12749    332520.0    76.0              -7.020       Blue
# 41          3365    340000.0    23.0              -6.200        Red
# 168        17383    342900.0    30.0              -6.090       Blue
# 222         9383    342940.0    98.0              -6.980       Blue
# 228        23095    347820.0    86.0              -5.905       Blue
# 109        33421    352000.0    67.0              -5.790       Blue
# 106        24630    363000.0    63.0              -5.830       Blue
# 169         9373    424520.0    24.0              -5.990       Blue
# 162        12675    452000.0    83.0              -5.620       Blue
# 223        23440    537430.0    81.0              -5.975       Blue
# 226         9892    593900.0    80.0              -7.262       Blue
# 229        21738    748890.0    92.0              -7.346       Blue
# 227        10930    783930.0    25.0              -6.224       Blue
# 101        40000    813000.0    14.0              -6.230       Blue
#
#     spectral_class    star_type
# 104              O  Super Giant
# 46               M  Super Giant
# 102              O  Super Giant
# 165              O  Super Giant
# 108              O  Super Giant
# 42               M  Super Giant
# 166              O  Super Giant
# 48               M  Super Giant
# 107              O  Super Giant
# 43               M  Super Giant
# 167              O  Super Giant
# 40               M  Super Giant
# 47               M  Super Giant
# 49               B  Super Giant
# 160              O  Super Giant
# 225              O  Super Giant
# 105              O  Super Giant
# 103              O  Super Giant
# 164              O  Super Giant
# 100              B  Super Giant
# 220              O  Super Giant
# 163              O  Super Giant
# 224              O  Super Giant
# 161              O  Super Giant
# 44               M  Super Giant
# 45               M  Super Giant
# 221              O  Super Giant
# 41               M  Super Giant
# 168              O  Super Giant
# 222              O  Super Giant
# 228              O  Super Giant
# 109              O  Super Giant
# 106              O  Super Giant
# 169              O  Super Giant
# 162              O  Super Giant
# 223              O  Super Giant
# 226              O  Super Giant
# 229              O  Super Giant
# 227              O  Super Giant
# 101              O  Super Giant

# %% [markdown]
# Questions 6
# Alright, now that we've found that there's a relationship between temperature and luminosity, and that we classify the stars based on their clusters. For my scientific paper I need you to help me determine the amount of each star in each classification. I now need you to create some density plots with the information I've given you.
#
# Density Plot Specifications:
#
# Create 4 density plots, one for temperature, one for luminosity, one for radius, and one for absolute magnitude (disregard the star type classes for this problem).
# The x axis should be the respective measurement, and the y axis should be density.
# These plots should not be log plots

# %%
# KDEs
plt.figure()
sns.kdeplot(data = star, x='temperature')
plt.show()
plt.figure()
sns.kdeplot(data = star, x='luminosity')
plt.show()
plt.figure()
sns.kdeplot(data = star, x='radius')
plt.show()
plt.figure()
sns.kdeplot(data = star, x='absolute_magnitude')
plt.show()

# %%
# Other Stats
# star['temperature'].mean()
# star['luminosity'].mean()
# star['radius'].var()
star['absolute_magnitude'].var()
# Out:
# 110.93381641588215

# %% [markdown]
# Stellar Property Correlation Values

# %%
# Temp v Rad
plt.figure()
sns.scatterplot(data=star, x='temperature', y='radius', hue='star_type')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Lum v Rad
sns.scatterplot(data=star, x='luminosity', y='radius', hue='star_type')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Absolute magnitude vs. Radius
plt.figure()
sns.scatterplot(data=star, x='absolute_magnitude', y='radius', hue='star_type')
plt.yscale('log')
plt.show()
# AB Mag v Lumin
plt.figure()
sns.scatterplot(data=star, x='absolute_magnitude', y='luminosity', hue='star_type')
plt.yscale('log')
plt.show()
# AB Mag v TEMP
plt.figure()
sns.scatterplot(data=star, x='absolute_magnitude', y='temperature', hue='star_type')
plt.yscale('log')
plt.show()

# %%
# Question 18 - correlation coefficient
rRadvTemp = np.corrcoef(star['temperature'],star['radius'])
print(rRadvTemp)
print(rRadvTemp[0,1]**2)
print()
rRadvLum = np.corrcoef(star['luminosity'],star['radius'])
print(rRadvLum)
print(rRadvLum[0,1]**2)
print()
rAMvLum = np.corrcoef(star['absolute_magnitude'],star['luminosity'])
print(rAMvLum)
print(rAMvLum[0,1]**2)
print()
rAMvRad = np.corrcoef(star['absolute_magnitude'],star['radius'])
print(rAMvRad)
print(rAMvRad[0,1]**2)
print()
rAMvTemp = np.corrcoef(star['absolute_magnitude'],star['temperature'])
print(rAMvTemp)
print(rAMvTemp[0,1]**2)
print()
# Out:
# [[1.         0.06421597]
#  [0.06421597 1.        ]]
# 0.004123691112044151
#
# [[1.         0.52651572]
#  [0.52651572 1.        ]]
# 0.27721880798570064
#
# [[ 1.         -0.69261923]
#  [-0.69261923  1.        ]]
# 0.4797214024755229
#
# [[ 1.         -0.60872823]
#  [-0.60872823  1.        ]]
# 0.3705500614644953
#
# [[ 1.         -0.42026054]
#  [-0.42026054  1.        ]]
# 0.17661892347268326
